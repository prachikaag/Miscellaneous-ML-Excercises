# %% [markdown]
# # Lab: SVMs on Extended MNIST
#
# In the [MNIST demo](demo_mnist_svm.ipynb), we saw how SVMs can be used for the classic MNIST problem of digit recognition. In this lab, we are going to extend the MNIST dataset by adding a number of non-digit letters and see if the classifier can distinguish the digits from the non-digits. All non-digits will be lumped as a single 11-th class. This is a highly simplified version of 'detection' problem (as opposed to 'classification' problem). Detection is vital in OCR and related problems since the non useful characters must be rejected.
#
# In addition to the concepts in the demo, you will learn:
# * Combine multiple datasets
# * Select the SVM parameters (`C` and `gamma`) via cross-validation.
# * Use the `GridSearchCV` method to search for parameters with cross-validation.
#
# Note:  An [earlier version](lab_emnist_2017_partial.ipynb) of this lab made you manually create the combined letter and digit data.  In this lab, we will download the data from NIST website.  But, the old lab is still useful to look at if you want to see how to use `skimage` package for a number of image pre-processing tasks.

# %% [markdown]
# As usual, we download the standard packages

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model, preprocessing

# %% [markdown]
# ## Downloading the EMNIST Dataset
#
# After creating the highly popular MNIST dataset, NIST created an extended version of the dataset to include letters and digits.     The extended datase (called EMNIST) also has many more examples per class.
#
# To download the data, first go to the [EMNIST webpage](https://www.nist.gov/itl/iad/image-group/emnist-dataset).  Near the bottom, you will see a link for `MATLAB format dataset`.  If you click on this link, you will download a `zip` file with several datasets in it.  The total file is 726M, so it may take some time and diskspace to download.  Extract two files:
# * `emnist-digits.mat`:  This is a file of digits `0` to `9`, but with more examples per class.
# * `emnist-letters.mat`:  This is a file of letters `a/A` to `z/Z`.  The lower and upper case letters are grouped into the same class.
#
# Once you get these two files, you can save yourself the diskspace and remove all the other files.
#
# You can download the files manually, or you can run the following commands which will download the files automatically.

# %%
from tqdm import tqdm
import requests
import os
import zipfile

def download_file(src_url, dst_fn):
    
    if os.path.exists(dst_fn):
        print('File %s already exists' % dst_fn)
        return
    
    print('Downloading %s' % dst_fn)
    
    # Streaming, so we can iterate over the response.
    r = requests.get(src_url, stream=True)

    # Total size in MB.
    total_size = int(r.headers.get('content-length', 0)); 
    block_size = 1024
    wrote = 0 
    with open(dst_fn, 'wb') as f:
        with tqdm(total=total_size//block_size, unit='kB', 
                           unit_scale=True, unit_divisor=1024) as pbar:
            for data in r.iter_content(block_size):
                wrote = wrote + len(data)
                pbar.update(1)
                f.write(data)
    if total_size != 0 and wrote != total_size:
        print("ERROR, something went wrong") 

# Get file names
matlab_dir = 'matlab'
digits_fn =  os.path.join(matlab_dir,'emnist-digits.mat')
letters_fn = os.path.join(matlab_dir,'emnist-letters.mat')

# Check if files exists
if os.path.exists(matlab_dir):
    if os.path.exists(digits_fn) and os.path.exists(letters_fn):
        print('Files already downloaded')
        files_exists = True
else:
    files_exists = False
    
if not files_exists:
    # First download the zip file if needed
    src_url = "http://www.itl.nist.gov/iaui/vip/cs_links/EMNIST/matlab.zip"
    dst_fn = 'matlab.zip'
    download_file(src_url, dst_fn)
    
    # Then, unzip the file
    print('Unzipping %s...' % dst_fn)
    zip_ref = zipfile.ZipFile(dst_fn, 'r')
    zip_ref.extractall('.')
    zip_ref.close()
    print('Unzip completed')
# Out:
# Files already downloaded

# %% [markdown]
# Since MATLAB files are still widely-used, Python has excellent routines for loading MATLAB files.  The function below uses the `scipy.io` package to extract the relevant fields from the MATLAB file.  Specifically, the function extracts the training and test data from MATLAB file.

# %%
import scipy.io
def load_emnist(file_path='emnist-digits.mat'):
    """
    Loads training and test data with ntr and nts training and test samples
    The `file_path` is the location of the `eminst-balanced.mat`.
    """    
    
    # Load the MATLAB file
    mat = scipy.io.loadmat(file_path)
    
    # Get the training data
    Xtr = mat['dataset'][0][0][0][0][0][0][:]
    ntr = Xtr.shape[0]
    ytr = mat['dataset'][0][0][0][0][0][1][:].reshape(ntr).astype(int)
    
    # Get the test data
    Xts = mat['dataset'][0][0][1][0][0][0][:]
    nts = Xts.shape[0]
    yts = mat['dataset'][0][0][1][0][0][1][:].reshape(nts).astype(int)
    
    print("%d training samples, %d test samples loaded" % (ntr, nts))

    return [Xtr, Xts, ytr, yts]

# %% [markdown]
# Use the function above to get all the digit images from the `emnist-digits.mat` file.

# %%
# TODO 1:  Load the digit data from emnist-digits.mat
# Xtr_dig, Xts_dig, ytr_dig, yts_dig = ...

Xtr_dig, Xts_dig, ytr_dig, yts_dig = load_emnist(digits_fn)
# Out:
# 240000 training samples, 40000 test samples loaded

# %% [markdown]
# Next, use the function above to get all the letter characters from the `emnist-letters.mat` file.

# %%
# TODO 2:  Load the digit data from emnist-letters.mat
# Xtr_let, Xts_let, ytr_let, yts_let = ...
Xtr_let, Xts_let, ytr_let, yts_let = load_emnist(letters_fn)
# Out:
# 124800 training samples, 20800 test samples loaded

# %% [markdown]
# We will use the function from the demo to plot the digits.

# %%
def plt_digit(x,y=None):
    nrow = 28
    ncol = 28
    xsq = x.reshape((nrow,ncol))
    plt.imshow(xsq.T,  cmap='Greys_r')
    plt.xticks([])
    plt.yticks([])    
    if y != None:
        plt.title('%d' % y)

# %% [markdown]
# Plot 8 random samples from the digit training data.  You can use the `plt_digit` function above with `subplot` to create a nice display.  You may want to size your plot with the `plt.figure(figsize=(10,20))` command.

# %%
# TODO 3:  Plot 8 random samples from the training data of the digits

nplt = 8
n_sample = Xtr_dig.shape[0]
Iperm = np.random.permutation(n_sample)

plt.figure(figsize=(10,3))
for i in range(nplt):
    ind = Iperm[i]
    plt.subplot(1,nplt,i+1)
    plt_digit(Xtr_dig[ind,:], ytr_dig[ind])

# %% [markdown]
# Next, plot 8 samples from the letters training data.  You should see that the labels go from 0 to 25 corresponding to `a` to `z`.  Upper and lower case letters belong to the same class.

# %%
# TODO 4:  Plot 8 random samples from the training data of the letters

nplt = 8
nsamp = Xtr_let.shape[0]
Iperm = np.random.permutation(nsamp)
plt.figure(figsize=(10,3)) 
for i in range(nplt):
    ind = Iperm[i]
    plt.subplot(1,nplt,i+1)
    plt_digit(Xtr_let[ind,:], ytr_let[ind])

# %% [markdown]
# ## Creating a Non-Digit Class
#
# SVM classifiers are VERY SLOW to train.  The training is particularly slow when there are a large number of classes, since the one classifier must be trained for each pair of labels.  To make the problem easier, we are going to lump all of the letters in one class and add that class to the digits.
#
# Before we begin, we first need to remove all the letters corresponding to `i/I`, `l/L` and `o/O`.  The reason is that these letters would get confused with the digits `0` and `1`.  Create arrays `Xtr_let_rem` and `ytr_let_rem` from the data `Xtr_let` and `ytr_let`, where the samples `i` with `ytr_let[i] == 9, 12` or `15` are removed.   Create `Xts_let_rem` and `yts_let_rem` similarly.
#
# If you are clever, you can do this without a for-loop via python broadcasting and `np.all(..., axis=1)` command.  But, you will receive full marks if you use a `for-loop`.

# %%
remove_list = np.array([9,12,15])

# TODO 5:  Create arrays with labels 9, 12 and 15 removed
# Xtr_let_rem, ytr_let_rem = ...
# Xts_let_rem, yts_let_rem = ...

I = np.all(ytr_let[:,None] != remove_list[None,:], axis=1) 
Xtr_let_rem = Xtr_let[I,:] 
ytr_let_rem = ytr_let[I]

I = np.all(yts_let[:,None] != remove_list[None,:], axis=1) 
Xts_let_rem = Xts_let[I,:]
yts_let_rem = yts_let[I]

# %% [markdown]
# Since training and testing an SVM is VERY SLOW, we will use only a small subset of the training and test data.  Of course, you will not get great results with this small dataset.  But, we can at least illustrate the basic concepts.
#
# Create arrays `Xtr1_dig` and `ytr1_dig` by selecting 5000 random training digit samples from `Xtr_dig` and `ytr_dig`.  Create arrays `Xtr1_let` and `ytr1_let` by selecting 1000 random training letter samples from `Xtr_let_rem` and `ytr_let_rem`.  Similarly, create test arrays `Xts1_dig,Xts1_let,yts1_dig,yts1_let` with 5000 digits and 1000 letters.

# %%
# Number of training and test digits and letters
ntr_dig = 5000
ntr_let = 1000
nts_dig = 5000
nts_let = 1000

# TODO 6 Create sub-sampled training and test data
# Xtr1_dig, ytr1_dig = ...
# Xts1_dig, yts1_dig = ...
# Xtr1_let, ytr1_let = ...
# Xts1_let, yts1_let = ...

def random_selection (X, y, n):
    n0 = X.shape[0]
    I = np.random.permutation(n0)
    X1 = X[I[:n],:]
    y1 = y[I[:n]]
    return X1, y1

Xtr1_dig, ytr1_dig = random_selection(Xtr_dig,ytr_dig,ntr_dig)
Xts1_dig, yts1_dig = random_selection(Xts_dig,yts_dig,nts_dig)
Xtr1_let, ytr1_let = random_selection(Xtr_let_rem,ytr_let_rem,ntr_let)
Xts1_let, yts1_let = random_selection(Xts_let_rem,yts_let_rem,nts_let)

# %% [markdown]
# Next, we create data by combining the digit and letter arrays.
# * Create an array `Xtr` by stacking `Xtr1_dig`, `Xtr1_let`.  This should result in 6000 total samples.
# * Create a new label vector `ytr` where `ytr[i] = ytr1_dig[i]` for any digit sample and `ytr[i]=10` for any letter sample.  Thus, all the letters are lumped into a single class with label 11.
#
# Create test arrays `Xts` and `yts` similarly.
#
# You may wish to use the `np.hstack` and `np.vstack` methods.

# %%
# TODO 7:  Create combined letter and digit training and test data
# Xtr, ytr = ..
# Xts, yts = ...


Xtr = np.vstack((Xtr1_dig,Xtr1_let))
ytr = np.hstack((ytr1_dig, 10*np.ones(ntr_let,dtype='int')))

Xts = np.vstack((Xts1_dig,Xts1_let))
yts = np.hstack((yts1_dig, 10*np.ones(nts_let,dtype='int')))

# %% [markdown]
# The training data above takes values from 0 to 255.  Rescale the data from -1 to 1.  This will get slightly better performance on the SVM.  Save the scaled data into arrays `Xtr1` and `Xts1`.

# %%
# TODO 8:  Rescale the data from -1 to 1
# Xtr1 = ...
# Xts1 = ...

Xtr1 = 2*Xtr/255.0 - 1
Xts1 = 2*Xts/255.0 - 1

# %% [markdown]
# ## Run the SVM classifier
#
# First create the SVM classifer. Use an `rbf` classifier with `C=2.8` and `gamma=.0073`. We will look at how to select these parameters laters.

# %%
from sklearn import svm

# TODO 9:  Create a classifier: a support vector classifier
# svc = ...

svc = svm.SVC(probability=False, kernel="rbf", C=2.8, gamma=.0073)

# %% [markdown]
# Fit the classifier using the scaled training data.  SVMs are insanely slow to train.  But, in this lab, we have kept the training size very small. So, the fitting should take about a minute or two.

# %%
# TODO 10:  Fit the classifier on the training data.

svc.fit(Xtr1,ytr)
# Out:
# SVC(C=2.8, gamma=0.0073)

# %% [markdown]
# Measure the accuracy on the test data.  This too will take another huge amount of time.  Print the accuracy.  If you did everything right, you should get an accuracy of around 89%.

# %%
# TODO 11:  Measure error on the test data

yhat = svc.predict(Xts1)
print(np.mean(yhat == yts))
# Out:
# 0.9006666666666666

# %% [markdown]
# The error rate is quite a bit higher than what we got in the digits only case.  Actually, had we done a classifier using all 36 labels instead of collapsing the letters to a single class, the SVM classifier would have done much better.  The reason is that the "letters" class is now extremely complex.
#
# Print a confusion matrix.  You should see that the error rate on the "letters" class is much higher.

# %%
# TODO 12:  Print a confusion matrix

from sklearn.metrics import confusion_matrix
C = confusion_matrix(yts,yhat)

# Normalize the confusion matrix
Csum = np.sum(C,1)
C = C / Csum[None,:]

# Print the confusion matrix
print(np.array_str(C, precision=3, suppress_small=True))
plt.imshow(C, interpolation='none')
plt.colorbar()
# Out:
# [[0.968 0.    0.    0.    0.002 0.    0.002 0.    0.    0.    0.014]
#  [0.    0.972 0.    0.    0.    0.002 0.    0.    0.002 0.    0.013]
#  [0.004 0.    0.918 0.    0.002 0.002 0.    0.004 0.002 0.    0.035]
#  [0.006 0.002 0.01  0.928 0.    0.004 0.    0.004 0.01  0.006 0.015]
#  [0.    0.002 0.    0.    0.896 0.    0.002 0.    0.002 0.014 0.039]
#  [0.002 0.    0.    0.014 0.    0.908 0.004 0.    0.004 0.    0.033]
#  [0.004 0.    0.002 0.    0.004 0.008 0.931 0.    0.    0.    0.025]
#  [0.002 0.    0.004 0.    0.004 0.    0.    0.958 0.002 0.02  0.006]
#  [0.    0.004 0.002 0.008 0.004 0.012 0.002 0.    0.866 0.008 0.045]
#  [0.002 0.002 0.    0.008 0.017 0.002 0.    0.019 0.004 0.926 0.009]
#  [0.045 0.048 0.06  0.04  0.079 0.067 0.041 0.021 0.029 0.043 0.764]]

# %% [markdown]
# Print:
# * What fraction of digits are mislabeled as letters?
# * What fraction of letters are mislabeled as digits?

# %%
# TODO 13:  Print above two error rates

err1 = np.mean((yhat == 10) & (yts < 10))
print('Digit -> letter error rate = %12.4e' % err1) 

err2 = np.mean((yhat < 10) & (yts == 10))
print('Letter -> digit error rate = %12.4e' % err2)
# Out:
# Digit -> letter error rate =   3.9000e-02
# Letter -> digit error rate =   3.9333e-02

# %% [markdown]
# ## Selecting gamma and C via Cross-Validation (Using For-Loops)
#
# In the above example, and in the demo, we used a given `gamma` and `C` value.  The selection of the parameters depend on the problem and decent performance of the SVM requires that you select these parameters carefully.  The best way to select the parameters is via cross validation.  Specifically, generally, one tries different values of `gamma` and `C` and selects the pair of values the lowest test error rate.
#
# In the code below, we will try to use 3 values for `C` and `gamma` as specified in the arrays `C_test` and `gam_test`.  For each `C` and `gamma` in these arrays, fit a model on the training data and measure the accuracy on the test data.  Then, print the `C` and `gamma` that result in the best accuracy.
#
# Normally, you would try a large number of values for each of the parameters, but an SVM is very slow to train -- even with this small data set.  So, we will just do 3 values of each.  Even then, this could take 30 minutes or so to complete.
#
# In this lab, you may do the parameter search over `C` and `gamma` in one of two ways:
# * This section:  Use for loops and manually search over the parameters.  This is more direct and you will see and control exactly what is happening.
# * Next section:  Use the `GridSearchCV` method in the `sklearn` package.  This takes a little reading, but once you learn this method, you can more easily use this for complex parameter searches.
#
# **You only need to submit the solutions to one of the two sections.**  Pick whichever one you want.

# %%
C_test = [0.1,1,10]
gam_test = [0.001,0.01,0.1]

nC = len(C_test)
ngam = len(gam_test)
acc = np.zeros((nC,ngam))

# TODO 14:  Measure and print the accuracy for each C and gamma value.  Store the results in acc

for i, C in enumerate(C_test):
    for j, gam in enumerate(gam_test):
                 
        svc = svm.SVC(probability=False, kernel="rbf", C=C, gamma=gam,verbose=10) # Fit the data
        svc.fit(Xtr1,ytr)
        yhat = svc.predict(Xts1)
        acc[i,j] = np.mean(yhat == yts)
        print('C=%12.4e gam=%12.4e acc=%f' % (C,gam,acc[i,j]))
# Out:
# [LibSVM]*
# optimization finished, #iter = 244
# obj = -29.118105, rho = -0.399202
# nSV = 472, nBSV = 462
# *
# optimization finished, #iter = 372
# obj = -52.021983, rho = 0.158470
# nSV = 739, nBSV = 734
# *
# optimization finished, #iter = 366
# obj = -48.055777, rho = -0.010835
# nSV = 713, nBSV = 700
# *
# optimization finished, #iter = 342
# obj = -42.617225, rho = 0.106801
# nSV = 647, nBSV = 632
# *
# optimization finished, #iter = 426
# obj = -58.801799, rho = 0.268378
# nSV = 824, nBSV = 816
# *
# optimization finished, #iter = 417
# obj = -55.754028, rho = -0.071291
# nSV = 808, nBSV = 798
# *
# optimization finished, #iter = 317
# obj = -40.235633, rho = -0.052627
# nSV = 616, nBSV = 604
# *
# optimization finished, #iter = 357
# obj = -46.914643, rho = 0.106472
# nSV = 694, nBSV = 687
# *
# optimization finished, #iter = 305
# obj = -38.852756, rho = -0.055876
# nSV = 593, nBSV = 582
# *
# optimization finished, #iter = 520
# obj = -77.635643, rho = 0.881417
# nSV = 976, nBSV = 964
# *
# optimization finished, #iter = 354
# obj = -46.069547, rho = 0.744584
# nSV = 694, nBSV = 686
# *
# optimization finished, #iter = 321
# obj = -39.980690, rho = 0.448612
# nSV = 632, nBSV = 626
# *
# optimization finished, #iter = 360
# obj = -47.983720, rho = 0.575403
# nSV = 708, nBSV = 700
# *
# optimization finished, #iter = 370
# obj = -48.384940, rho = 0.748871
# nSV = 731, nBSV = 723
# *
# optimization finished, #iter = 320
# obj = -40.066983, rho = 0.390715
# nSV = 631, nBSV = 624
# *
# optimization finished, #iter = 361
# obj = -49.604269, rho = 0.387589
# nSV = 713, nBSV = 707
# *
# optimization finished, #iter = 378
# obj = -52.007704, rho = 0.609714
# nSV = 747, nBSV = 738
# *
# optimization finished, #iter = 368
# obj = -48.702598, rho = 0.397942
# nSV = 730, nBSV = 722
# *
# optimization finished, #iter = 495
# obj = -70.560327, rho = 1.441048
# nSV = 972, nBSV = 961
# *
# optimization finished, #iter = 405
# obj = -54.442698, rho = -0.190818
# nSV = 783, nBSV = 768
# *
# optimization finished, #iter = 374
# obj = -48.961849, rho = -0.118527
# nSV = 738, nBSV = 732
# *
# optimization finished, #iter = 428
# obj = -59.830265, rho = 0.050379
# nSV = 850, nBSV = 841
# *
# optimization finished, #iter = 445
# obj = -62.706454, rho = -0.299962
# nSV = 877, nBSV = 874
# *
# optimization finished, #iter = 417
# obj = -55.679855, rho = -0.248959
# nSV = 812, nBSV = 801
# *
# optimization finished, #iter = 447
# obj = -62.870859, rho = -0.075174
# nSV = 876, nBSV = 866
# *
# optimization finished, #iter = 365
# obj = -48.182291, rho = -0.208213
# nSV = 723, nBSV = 716
# *
# optimization finished, #iter = 536
# obj = -84.414716, rho = 0.896080
# nSV = 971, nBSV = 953
# *
# optimization finished, #iter = 362
# obj = -45.027246, rho = 0.128291
# nSV = 697, nBSV = 687
# *
# optimization finished, #iter = 416
# obj = -61.990078, rho = 0.075046
# nSV = 822, nBSV = 815
# *
# optimization finished, #iter = 376
# obj = -48.427055, rho = -0.050018
# nSV = 733, nBSV = 722
# *
# optimization finished, #iter = 423
# obj = -55.931436, rho = 0.006446
# nSV = 826, nBSV = 817
# *
# optimization finished, #iter = 435
# obj = -61.151994, rho = 0.095338
# nSV = 854, nBSV = 847
# *
# optimization finished, #iter = 419
# obj = -55.845348, rho = 0.017177
# nSV = 824, nBSV = 816
# *
# optimization finished, #iter = 494
# obj = -74.644350, rho = 0.762245
# nSV = 965, nBSV = 955
# *
# optimization finished, #iter = 444
# obj = -61.356972, rho = 0.155686
# nSV = 879, nBSV = 870
# *
# optimization finished, #iter = 383
# obj = -49.032956, rho = -0.121796
# nSV = 745, nBSV = 734
# *
# optimization finished, #iter = 430
# obj = -57.512346, rho = -0.208518
# nSV = 847, nBSV = 837
# *
# optimization finished, #iter = 438
# obj = -59.933495, rho = 0.042018
# nSV = 858, nBSV = 846
# *
# optimization finished, #iter = 477
# obj = -72.006647, rho = -0.185917
# nSV = 948, nBSV = 941
# *
# optimization finished, #iter = 588
# obj = -95.737368, rho = 1.103846
# nSV = 1070, nBSV = 1061
# *
# optimization finished, #iter = 445
# obj = -63.043863, rho = -0.306125
# nSV = 884, nBSV = 880
# *
# optimization finished, #iter = 415
# obj = -56.628312, rho = -0.340000
# nSV = 827, nBSV = 820
# *
# optimization finished, #iter = 478
# obj = -71.687109, rho = -0.214674
# nSV = 950, nBSV = 947
# *
# optimization finished, #iter = 437
# obj = -61.250965, rho = -0.328736
# nSV = 868, nBSV = 862
# *
# optimization finished, #iter = 576
# obj = -91.506600, rho = 1.025673
# nSV = 1000, nBSV = 985
# *
# optimization finished, #iter = 308
# obj = -37.239028, rho = -0.000854
# nSV = 596, nBSV = 584
# *
# optimization finished, #iter = 404
# obj = -54.234836, rho = 0.157828
# nSV = 793, nBSV = 785
# *
# optimization finished, #iter = 316
# obj = -38.976917, rho = -0.027750
# nSV = 621, nBSV = 611
# *
# optimization finished, #iter = 555
# obj = -83.961564, rho = 1.079183
# nSV = 1062, nBSV = 1047
# *
# optimization finished, #iter = 430
# obj = -59.158462, rho = 0.268601
# nSV = 837, nBSV = 827
# *
# optimization finished, #iter = 486
# obj = -75.342221, rho = 0.075188
# nSV = 967, nBSV = 962
# *
# optimization finished, #iter = 521
# obj = -76.615797, rho = 0.939733
# nSV = 1004, nBSV = 993
# *
# optimization finished, #iter = 489
# obj = -71.027801, rho = -0.198596
# nSV = 952, nBSV = 948
# *
# optimization finished, #iter = 555
# obj = -90.497803, rho = 1.023466
# nSV = 1011, nBSV = 995
# *
# optimization finished, #iter = 525
# obj = -81.141250, rho = 1.090198
# nSV = 993, nBSV = 981
# Total nSV = 5988
# C=  1.0000e-01 gam=  1.0000e-03 acc=0.524167
# [LibSVM]*
# optimization finished, #iter = 144
# obj = -11.481596, rho = -0.590950
# nSV = 207, nBSV = 167
# *
# optimization finished, #iter = 288
# obj = -27.651591, rho = 0.205969
# nSV = 447, nBSV = 398
# *
# optimization finished, #iter = 243
# obj = -23.736756, rho = -0.056498
# nSV = 391, nBSV = 354
# *
# optimization finished, #iter = 233
# obj = -21.016889, rho = 0.091223
# nSV = 357, nBSV = 306
# *
# optimization finished, #iter = 299
# obj = -31.171565, rho = 0.238109
# nSV = 490, nBSV = 441
# *
# optimization finished, #iter = 275
# obj = -27.435741, rho = -0.204088
# nSV = 454, nBSV = 406
# *
# optimization finished, #iter = 219
# obj = -18.332017, rho = -0.172089
# nSV = 320, nBSV = 273
# *
# optimization finished, #iter = 244
# obj = -24.266042, rho = 0.120048
# nSV = 390, nBSV = 352
# *
# optimization finished, #iter = 212
# obj = -18.507555, rho = -0.167348
# nSV = 322, nBSV = 266
# *
# optimization finished, #iter = 419
# obj = -50.184051, rho = 1.077730
# nSV = 689, nBSV = 634
# *
# optimization finished, #iter = 195
# obj = -18.188242, rho = 0.996545
# nSV = 305, nBSV = 264
# *
# optimization finished, #iter = 174
# obj = -15.832976, rho = 0.630134
# nSV = 267, nBSV = 229
# *
# optimization finished, #iter = 224
# obj = -19.940948, rho = 0.847468
# nSV = 331, nBSV = 289
# *
# optimization finished, #iter = 207
# obj = -18.428373, rho = 0.993327
# nSV = 315, nBSV = 269
# *
# optimization finished, #iter = 171
# obj = -15.547591, rho = 0.573436
# nSV = 268, nBSV = 228
# *
# optimization finished, #iter = 210
# obj = -21.134301, rho = 0.621746
# nSV = 344, nBSV = 312
# *
# optimization finished, #iter = 216
# obj = -22.792864, rho = 0.922940
# nSV = 359, nBSV = 321
# *
# optimization finished, #iter = 208
# obj = -19.402326, rho = 0.562320
# nSV = 325, nBSV = 290
# *
# optimization finished, #iter = 284
# obj = -32.594351, rho = 1.795096
# nSV = 479, nBSV = 434
# *
# optimization finished, #iter = 307
# obj = -29.671237, rho = -0.256386
# nSV = 476, nBSV = 417
# *
# optimization finished, #iter = 268
# obj = -24.305186, rho = -0.162220
# nSV = 412, nBSV = 356
# *
# optimization finished, #iter = 315
# obj = -31.576140, rho = -0.011391
# nSV = 507, nBSV = 453
# *
# optimization finished, #iter = 308
# obj = -30.971584, rho = -0.510384
# nSV = 506, nBSV = 455
# *
# optimization finished, #iter = 287
# obj = -26.719884, rho = -0.373902
# nSV = 454, nBSV = 403
# *
# optimization finished, #iter = 350
# obj = -34.838061, rho = -0.106529
# nSV = 552, nBSV = 487
# *
# optimization finished, #iter = 250
# obj = -23.316352, rho = -0.247077
# nSV = 395, nBSV = 346
# *
# optimization finished, #iter = 486
# obj = -59.355446, rho = 0.927450
# nSV = 816, nBSV = 761
# *
# optimization finished, #iter = 245
# obj = -20.635044, rho = 0.130480
# nSV = 364, nBSV = 306
# *
# optimization finished, #iter = 322
# obj = -36.878059, rho = 0.244016
# nSV = 549, nBSV = 505
# *
# optimization finished, #iter = 238
# obj = -22.043813, rho = -0.081992
# nSV = 378, nBSV = 331
# *
# optimization finished, #iter = 273
# obj = -25.711191, rho = 0.004928
# nSV = 432, nBSV = 383
# *
# optimization finished, #iter = 307
# obj = -34.560782, rho = 0.190786
# nSV = 521, nBSV = 474
# *
# optimization finished, #iter = 276
# obj = -26.674089, rho = 0.047249
# nSV = 440, nBSV = 391
# *
# optimization finished, #iter = 376
# obj = -46.154508, rho = 0.971993
# nSV = 653, nBSV = 603
# *
# optimization finished, #iter = 320
# obj = -30.376934, rho = 0.193757
# nSV = 507, nBSV = 440
# *
# optimization finished, #iter = 269
# obj = -22.486931, rho = -0.193471
# nSV = 396, nBSV = 324
# *
# optimization finished, #iter = 287
# obj = -27.676384, rho = -0.342190
# nSV = 455, nBSV = 407
# *
# optimization finished, #iter = 297
# obj = -31.635363, rho = 0.086841
# nSV = 501, nBSV = 452
# *
# optimization finished, #iter = 367
# obj = -41.657411, rho = -0.256628
# nSV = 620, nBSV = 573
# *
# optimization finished, #iter = 527
# obj = -67.250673, rho = 1.193451
# nSV = 897, nBSV = 839
# *
# optimization finished, #iter = 309
# obj = -31.165028, rho = -0.465693
# nSV = 507, nBSV = 457
# *
# optimization finished, #iter = 274
# obj = -26.234456, rho = -0.468592
# nSV = 445, nBSV = 390
# *
# optimization finished, #iter = 373
# obj = -40.297518, rho = -0.263116
# nSV = 613, nBSV = 552
# *
# optimization finished, #iter = 298
# obj = -29.429008, rho = -0.455821
# nSV = 487, nBSV = 432
# *
# optimization finished, #iter = 544
# obj = -67.119571, rho = 1.053722
# nSV = 897, nBSV = 833
# *
# optimization finished, #iter = 203
# obj = -15.142782, rho = -0.009795
# nSV = 282, nBSV = 226
# *
# optimization finished, #iter = 273
# obj = -26.856939, rho = 0.295964
# nSV = 440, nBSV = 390
# *
# optimization finished, #iter = 194
# obj = -16.748674, rho = 0.021662
# nSV = 301, nBSV = 251
# *
# optimization finished, #iter = 413
# obj = -49.964100, rho = 1.278369
# nSV = 716, nBSV = 666
# *
# optimization finished, #iter = 298
# obj = -30.243617, rho = 0.369331
# nSV = 483, nBSV = 423
# *
# optimization finished, #iter = 389
# obj = -42.732892, rho = 0.214200
# nSV = 636, nBSV = 584
# *
# optimization finished, #iter = 361
# obj = -42.443250, rho = 1.190661
# nSV = 628, nBSV = 586
# *
# optimization finished, #iter = 353
# obj = -38.868328, rho = -0.323413
# nSV = 592, nBSV = 549
# *
# optimization finished, #iter = 515
# obj = -65.652634, rho = 1.174862
# nSV = 864, nBSV = 806
# *
# optimization finished, #iter = 420
# obj = -48.811408, rho = 1.230139
# nSV = 697, nBSV = 633
# Total nSV = 5033
# C=  1.0000e-01 gam=  1.0000e-02 acc=0.816667
# [LibSVM]*
# optimization finished, #iter = 719
# obj = -58.927238, rho = -0.876002
# nSV = 932, nBSV = 662
# *
# optimization finished, #iter = 524
# obj = -90.422431, rho = -0.826522
# nSV = 970, nBSV = 934
# *
# optimization finished, #iter = 518
# obj = -90.358828, rho = -0.818458
# nSV = 972, nBSV = 941
# *
# optimization finished, #iter = 750
# obj = -91.638658, rho = 0.879158
# nSV = 1022, nBSV = 786
# *
# optimization finished, #iter = 570
# obj = -91.665966, rho = 0.869266
# nSV = 985, nBSV = 915
# *
# optimization finished, #iter = 645
# obj = -91.128719, rho = 0.827710
# nSV = 1017, nBSV = 882
# *
# optimization finished, #iter = 540
# obj = -90.205135, rho = 0.750686
# nSV = 992, nBSV = 937
# *
# optimization finished, #iter = 614
# obj = -91.665321, rho = 0.872335
# nSV = 991, nBSV = 890
# *
# optimization finished, #iter = 507
# obj = -90.379407, rho = 0.711537
# nSV = 982, nBSV = 968
# .*
# optimization finished, #iter = 1608
# obj = -93.233342, rho = 0.949792
# nSV = 1489, nBSV = 491
# *.*
# optimization finished, #iter = 1091
# obj = -59.537944, rho = 0.904827
# nSV = 926, nBSV = 461
# *
# optimization finished, #iter = 759
# obj = -59.311064, rho = 0.890628
# nSV = 928, nBSV = 638
# *.*
# optimization finished, #iter = 1012
# obj = -59.847499, rho = 0.904164
# nSV = 980, nBSV = 498
# *.*
# optimization finished, #iter = 991
# obj = -59.427868, rho = 0.901086
# nSV = 941, nBSV = 450
# *
# optimization finished, #iter = 778
# obj = -59.155723, rho = 0.875309
# nSV = 970, nBSV = 658
# *
# optimization finished, #iter = 695
# obj = -59.622044, rho = 0.853269
# nSV = 948, nBSV = 718
# *.*
# optimization finished, #iter = 1017
# obj = -59.768496, rho = 0.904838
# nSV = 949, nBSV = 489
# *
# optimization finished, #iter = 678
# obj = -59.418232, rho = 0.858320
# nSV = 934, nBSV = 728
# .*.*
# optimization finished, #iter = 2076
# obj = -61.578200, rho = 0.960693
# nSV = 1456, nBSV = 478
# *
# optimization finished, #iter = 495
# obj = -90.677080, rho = 0.823138
# nSV = 964, nBSV = 953
# *
# optimization finished, #iter = 787
# obj = -90.923069, rho = 0.883504
# nSV = 1014, nBSV = 735
# *
# optimization finished, #iter = 626
# obj = -90.918077, rho = 0.878289
# nSV = 977, nBSV = 855
# *
# optimization finished, #iter = 657
# obj = -90.327986, rho = 0.833582
# nSV = 1008, nBSV = 855
# *
# optimization finished, #iter = 577
# obj = -89.675119, rho = 0.774153
# nSV = 984, nBSV = 902
# *
# optimization finished, #iter = 680
# obj = -90.978912, rho = 0.881363
# nSV = 983, nBSV = 822
# *
# optimization finished, #iter = 525
# obj = -89.802004, rho = 0.762762
# nSV = 974, nBSV = 933
# .*
# optimization finished, #iter = 1880
# obj = -92.432526, rho = 0.950170
# nSV = 1481, nBSV = 481
# *
# optimization finished, #iter = 783
# obj = -90.876683, rho = 0.882963
# nSV = 1016, nBSV = 747
# *
# optimization finished, #iter = 604
# obj = -90.961736, rho = 0.876828
# nSV = 979, nBSV = 874
# *
# optimization finished, #iter = 654
# obj = -90.270559, rho = 0.831661
# nSV = 1010, nBSV = 862
# *
# optimization finished, #iter = 561
# obj = -89.617450, rho = 0.771023
# nSV = 986, nBSV = 912
# *
# optimization finished, #iter = 664
# obj = -91.000554, rho = 0.881638
# nSV = 985, nBSV = 840
# *
# optimization finished, #iter = 518
# obj = -89.821619, rho = 0.758923
# nSV = 976, nBSV = 944
# .*
# optimization finished, #iter = 1845
# obj = -92.404784, rho = 0.950315
# nSV = 1483, nBSV = 483
# *
# optimization finished, #iter = 730
# obj = -93.460035, rho = -0.876458
# nSV = 1029, nBSV = 825
# *
# optimization finished, #iter = 567
# obj = -97.973112, rho = -0.829170
# nSV = 1061, nBSV = 1028
# *
# optimization finished, #iter = 693
# obj = -93.688434, rho = -0.874612
# nSV = 1039, nBSV = 869
# *
# optimization finished, #iter = 704
# obj = -94.551231, rho = -0.872997
# nSV = 1035, nBSV = 860
# *
# optimization finished, #iter = 816
# obj = -92.097811, rho = -0.890727
# nSV = 1026, nBSV = 749
# .*
# optimization finished, #iter = 1898
# obj = -101.827340, rho = 0.946453
# nSV = 1533, nBSV = 533
# *
# optimization finished, #iter = 620
# obj = -92.779279, rho = 0.814038
# nSV = 1023, nBSV = 916
# *
# optimization finished, #iter = 530
# obj = -91.933766, rho = 0.727502
# nSV = 1001, nBSV = 969
# *
# optimization finished, #iter = 561
# obj = -93.504780, rho = 0.863746
# nSV = 998, nBSV = 940
# *
# optimization finished, #iter = 532
# obj = -91.649006, rho = -0.860643
# nSV = 989, nBSV = 955
# .*
# optimization finished, #iter = 1281
# obj = -95.074600, rho = 0.949348
# nSV = 1496, nBSV = 496
# *
# optimization finished, #iter = 586
# obj = -92.698452, rho = -0.792245
# nSV = 1033, nBSV = 961
# *
# optimization finished, #iter = 603
# obj = -93.810860, rho = -0.803220
# nSV = 1029, nBSV = 942
# *
# optimization finished, #iter = 626
# obj = -90.902008, rho = -0.816752
# nSV = 1020, nBSV = 903
# .*
# optimization finished, #iter = 1826
# obj = -99.925735, rho = 0.946465
# nSV = 1528, nBSV = 532
# *
# optimization finished, #iter = 513
# obj = -93.025953, rho = -0.694892
# nSV = 1008, nBSV = 996
# *
# optimization finished, #iter = 536
# obj = -91.123141, rho = -0.773527
# nSV = 998, nBSV = 957
# .*
# optimization finished, #iter = 1358
# obj = -95.243685, rho = 0.948786
# nSV = 1506, nBSV = 509
# *
# optimization finished, #iter = 594
# obj = -91.887216, rho = -0.878673
# nSV = 995, nBSV = 900
# .*
# optimization finished, #iter = 1343
# obj = -96.196641, rho = 0.948940
# nSV = 1502, nBSV = 502
# .*
# optimization finished, #iter = 1801
# obj = -93.309671, rho = 0.950870
# nSV = 1493, nBSV = 498
# Total nSV = 5967
# C=  1.0000e-01 gam=  1.0000e-01 acc=0.226833
# [LibSVM]*
# optimization finished, #iter = 106
# obj = -75.632098, rho = -0.645393
# nSV = 129, nBSV = 107
# *
# optimization finished, #iter = 219
# obj = -181.222839, rho = 0.193163
# nSV = 291, nBSV = 253
# *
# optimization finished, #iter = 193
# obj = -152.383835, rho = -0.124768
# nSV = 247, nBSV = 213
# *
# optimization finished, #iter = 170
# obj = -127.724288, rho = 0.039390
# nSV = 211, nBSV = 178
# *
# optimization finished, #iter = 260
# obj = -220.008698, rho = 0.420390
# nSV = 337, nBSV = 300
# *
# optimization finished, #iter = 219
# obj = -172.475068, rho = -0.343510
# nSV = 291, nBSV = 252
# *
# optimization finished, #iter = 173
# obj = -109.978726, rho = -0.275100
# nSV = 194, nBSV = 159
# *
# optimization finished, #iter = 211
# obj = -151.198336, rho = 0.116630
# nSV = 248, nBSV = 209
# *
# optimization finished, #iter = 148
# obj = -115.482273, rho = -0.249344
# nSV = 192, nBSV = 164
# *
# optimization finished, #iter = 369
# obj = -425.088433, rho = 1.797737
# nSV = 555, nBSV = 519
# *
# optimization finished, #iter = 158
# obj = -136.214279, rho = 1.271088
# nSV = 223, nBSV = 192
# *
# optimization finished, #iter = 128
# obj = -115.111337, rho = 0.610773
# nSV = 182, nBSV = 159
# *
# optimization finished, #iter = 176
# obj = -148.389049, rho = 1.094407
# nSV = 240, nBSV = 212
# *
# optimization finished, #iter = 149
# obj = -141.937530, rho = 1.427996
# nSV = 229, nBSV = 204
# *
# optimization finished, #iter = 142
# obj = -110.480728, rho = 0.552058
# nSV = 184, nBSV = 156
# *
# optimization finished, #iter = 177
# obj = -157.350757, rho = 0.715349
# nSV = 254, nBSV = 231
# *
# optimization finished, #iter = 206
# obj = -185.986030, rho = 1.043760
# nSV = 288, nBSV = 248
# *
# optimization finished, #iter = 165
# obj = -139.662580, rho = 0.561702
# nSV = 234, nBSV = 206
# *
# optimization finished, #iter = 278
# obj = -304.356519, rho = 3.142050
# nSV = 423, nBSV = 391
# *
# optimization finished, #iter = 235
# obj = -191.028926, rho = -0.254308
# nSV = 310, nBSV = 264
# *
# optimization finished, #iter = 200
# obj = -149.609207, rho = -0.191789
# nSV = 242, nBSV = 205
# *
# optimization finished, #iter = 235
# obj = -212.361515, rho = 0.085230
# nSV = 334, nBSV = 292
# *
# optimization finished, #iter = 259
# obj = -214.178413, rho = -0.926846
# nSV = 343, nBSV = 297
# *
# optimization finished, #iter = 226
# obj = -167.998789, rho = -0.417226
# nSV = 284, nBSV = 248
# *
# optimization finished, #iter = 267
# obj = -233.543121, rho = -0.210647
# nSV = 359, nBSV = 319
# *
# optimization finished, #iter = 196
# obj = -144.393787, rho = -0.320197
# nSV = 237, nBSV = 200
# *
# optimization finished, #iter = 405
# obj = -472.047682, rho = 1.560685
# nSV = 622, nBSV = 583
# *
# optimization finished, #iter = 170
# obj = -121.904579, rho = 0.172436
# nSV = 210, nBSV = 176
# *
# optimization finished, #iter = 289
# obj = -268.465712, rho = 0.609895
# nSV = 395, nBSV = 353
# *
# optimization finished, #iter = 171
# obj = -133.738509, rho = -0.032750
# nSV = 228, nBSV = 198
# *
# optimization finished, #iter = 242
# obj = -170.994870, rho = 0.042648
# nSV = 281, nBSV = 240
# *
# optimization finished, #iter = 248
# obj = -244.370129, rho = 0.345718
# nSV = 358, nBSV = 324
# *
# optimization finished, #iter = 253
# obj = -174.568241, rho = 0.217162
# nSV = 286, nBSV = 240
# *
# optimization finished, #iter = 320
# obj = -363.935280, rho = 1.748510
# nSV = 491, nBSV = 451
# *
# optimization finished, #iter = 232
# obj = -205.859998, rho = 0.387229
# nSV = 328, nBSV = 287
# *
# optimization finished, #iter = 187
# obj = -138.745136, rho = -0.264646
# nSV = 233, nBSV = 197
# *
# optimization finished, #iter = 225
# obj = -181.377837, rho = -0.499030
# nSV = 296, nBSV = 258
# *
# optimization finished, #iter = 262
# obj = -212.599989, rho = 0.210643
# nSV = 338, nBSV = 294
# *
# optimization finished, #iter = 289
# obj = -304.134951, rho = -0.385333
# nSV = 444, nBSV = 414
# *
# optimization finished, #iter = 515
# obj = -577.290734, rho = 2.010615
# nSV = 740, nBSV = 685
# *
# optimization finished, #iter = 247
# obj = -212.000628, rho = -0.861188
# nSV = 338, nBSV = 299
# *
# optimization finished, #iter = 232
# obj = -171.071816, rho = -0.713694
# nSV = 290, nBSV = 250
# *
# optimization finished, #iter = 341
# obj = -291.944814, rho = -0.625581
# nSV = 438, nBSV = 377
# *
# optimization finished, #iter = 226
# obj = -201.600590, rho = -0.756458
# nSV = 317, nBSV = 283
# *
# optimization finished, #iter = 519
# obj = -593.484947, rho = 1.833764
# nSV = 755, nBSV = 709
# *
# optimization finished, #iter = 173
# obj = -85.346880, rho = -0.042872
# nSV = 170, nBSV = 123
# *
# optimization finished, #iter = 207
# obj = -171.113166, rho = 0.477200
# nSV = 276, nBSV = 240
# *
# optimization finished, #iter = 134
# obj = -100.195624, rho = 0.036446
# nSV = 175, nBSV = 148
# *
# optimization finished, #iter = 383
# obj = -410.606332, rho = 2.373413
# nSV = 566, nBSV = 517
# *
# optimization finished, #iter = 238
# obj = -214.836092, rho = 0.656628
# nSV = 338, nBSV = 304
# *
# optimization finished, #iter = 304
# obj = -324.786247, rho = 0.392571
# nSV = 466, nBSV = 432
# *
# optimization finished, #iter = 334
# obj = -331.188999, rho = 2.166285
# nSV = 479, nBSV = 435
# *
# optimization finished, #iter = 287
# obj = -284.035743, rho = -0.393265
# nSV = 418, nBSV = 388
# *
# optimization finished, #iter = 484
# obj = -576.708024, rho = 2.340434
# nSV = 713, nBSV = 662
# *
# optimization finished, #iter = 362
# obj = -400.146464, rho = 2.267911
# nSV = 542, nBSV = 500
# Total nSV = 4484
# C=  1.0000e+00 gam=  1.0000e-03 acc=0.817167
# [LibSVM]*
# optimization finished, #iter = 154
# obj = -24.706037, rho = -0.441126
# nSV = 86, nBSV = 20
# *
# optimization finished, #iter = 361
# obj = -60.993213, rho = 0.202925
# nSV = 198, nBSV = 47
# *
# optimization finished, #iter = 338
# obj = -52.830807, rho = -0.031724
# nSV = 186, nBSV = 43
# *
# optimization finished, #iter = 319
# obj = -45.629869, rho = 0.163097
# nSV = 167, nBSV = 34
# *
# optimization finished, #iter = 468
# obj = -78.688658, rho = 0.406424
# nSV = 243, nBSV = 62
# *
# optimization finished, #iter = 370
# obj = -58.581404, rho = -0.148605
# nSV = 189, nBSV = 45
# *
# optimization finished, #iter = 267
# obj = -35.074591, rho = -0.148636
# nSV = 136, nBSV = 21
# *
# optimization finished, #iter = 337
# obj = -57.242862, rho = 0.205044
# nSV = 188, nBSV = 44
# *
# optimization finished, #iter = 245
# obj = -44.250923, rho = -0.108713
# nSV = 141, nBSV = 34
# *
# optimization finished, #iter = 704
# obj = -200.356934, rho = 1.461555
# nSV = 435, nBSV = 202
# *
# optimization finished, #iter = 241
# obj = -47.119724, rho = 0.950836
# nSV = 137, nBSV = 40
# *
# optimization finished, #iter = 211
# obj = -42.380093, rho = 0.317269
# nSV = 119, nBSV = 38
# *
# optimization finished, #iter = 269
# obj = -48.464696, rho = 0.815410
# nSV = 144, nBSV = 45
# *
# optimization finished, #iter = 228
# obj = -45.746518, rho = 1.008911
# nSV = 133, nBSV = 38
# *
# optimization finished, #iter = 193
# obj = -38.783894, rho = 0.216497
# nSV = 115, nBSV = 37
# *
# optimization finished, #iter = 274
# obj = -52.020327, rho = 0.521519
# nSV = 147, nBSV = 56
# *
# optimization finished, #iter = 265
# obj = -64.950123, rho = 0.828457
# nSV = 160, nBSV = 67
# *
# optimization finished, #iter = 253
# obj = -43.768512, rho = 0.426224
# nSV = 140, nBSV = 39
# *
# optimization finished, #iter = 419
# obj = -129.052913, rho = 2.395391
# nSV = 258, nBSV = 128
# *
# optimization finished, #iter = 377
# obj = -77.813927, rho = -0.233669
# nSV = 224, nBSV = 73
# *
# optimization finished, #iter = 323
# obj = -57.740138, rho = -0.127385
# nSV = 191, nBSV = 46
# *
# optimization finished, #iter = 396
# obj = -77.815094, rho = 0.090945
# nSV = 235, nBSV = 67
# *
# optimization finished, #iter = 408
# obj = -69.664960, rho = -0.800882
# nSV = 227, nBSV = 59
# *
# optimization finished, #iter = 373
# obj = -57.622476, rho = -0.201156
# nSV = 192, nBSV = 44
# *
# optimization finished, #iter = 440
# obj = -92.149606, rho = 0.017169
# nSV = 262, nBSV = 83
# *
# optimization finished, #iter = 330
# obj = -53.078981, rho = -0.062514
# nSV = 177, nBSV = 41
# *
# optimization finished, #iter = 833
# obj = -245.142236, rho = 1.479536
# nSV = 520, nBSV = 237
# *
# optimization finished, #iter = 310
# obj = -42.313219, rho = 0.151901
# nSV = 164, nBSV = 28
# *
# optimization finished, #iter = 478
# obj = -114.534863, rho = 0.444629
# nSV = 297, nBSV = 115
# *
# optimization finished, #iter = 294
# obj = -43.451097, rho = -0.022507
# nSV = 158, nBSV = 27
# *
# optimization finished, #iter = 397
# obj = -59.218407, rho = 0.040352
# nSV = 198, nBSV = 41
# *
# optimization finished, #iter = 390
# obj = -105.409243, rho = 0.374482
# nSV = 256, nBSV = 106
# *
# optimization finished, #iter = 365
# obj = -67.156477, rho = 0.242550
# nSV = 198, nBSV = 53
# *
# optimization finished, #iter = 561
# obj = -182.824002, rho = 1.689825
# nSV = 379, nBSV = 198
# *
# optimization finished, #iter = 419
# obj = -68.630118, rho = 0.154223
# nSV = 213, nBSV = 49
# *
# optimization finished, #iter = 330
# obj = -49.293211, rho = -0.304209
# nSV = 175, nBSV = 40
# *
# optimization finished, #iter = 324
# obj = -68.225813, rho = -0.464020
# nSV = 191, nBSV = 68
# *
# optimization finished, #iter = 500
# obj = -78.959784, rho = 0.032727
# nSV = 256, nBSV = 64
# *
# optimization finished, #iter = 500
# obj = -128.447378, rho = -0.516173
# nSV = 313, nBSV = 134
# *
# optimization finished, #iter = 866
# obj = -299.610238, rho = 1.363546
# nSV = 585, nBSV = 330
# *
# optimization finished, #iter = 376
# obj = -76.246113, rho = -0.692520
# nSV = 220, nBSV = 71
# *
# optimization finished, #iter = 374
# obj = -52.121143, rho = -0.459530
# nSV = 192, nBSV = 36
# *
# optimization finished, #iter = 588
# obj = -117.632834, rho = -0.326101
# nSV = 313, nBSV = 98
# *
# optimization finished, #iter = 389
# obj = -71.785891, rho = -0.448504
# nSV = 220, nBSV = 59
# *
# optimization finished, #iter = 973
# obj = -278.235482, rho = 1.399037
# nSV = 592, nBSV = 275
# *
# optimization finished, #iter = 221
# obj = -24.818003, rho = 0.064337
# nSV = 110, nBSV = 9
# *
# optimization finished, #iter = 302
# obj = -62.150653, rho = 0.489479
# nSV = 181, nBSV = 54
# *
# optimization finished, #iter = 237
# obj = -33.504023, rho = 0.151638
# nSV = 121, nBSV = 21
# *
# optimization finished, #iter = 609
# obj = -181.317152, rho = 2.021913
# nSV = 397, nBSV = 192
# *
# optimization finished, #iter = 451
# obj = -73.104899, rho = 0.372867
# nSV = 230, nBSV = 58
# *
# optimization finished, #iter = 463
# obj = -146.216290, rho = 0.237973
# nSV = 306, nBSV = 158
# *
# optimization finished, #iter = 544
# obj = -134.365424, rho = 1.802360
# nSV = 324, nBSV = 136
# *
# optimization finished, #iter = 522
# obj = -112.382211, rho = -0.136231
# nSV = 294, nBSV = 109
# *
# optimization finished, #iter = 821
# obj = -305.734786, rho = 2.213874
# nSV = 599, nBSV = 330
# *
# optimization finished, #iter = 650
# obj = -192.401407, rho = 1.738788
# nSV = 412, nBSV = 197
# Total nSV = 3636
# C=  1.0000e+00 gam=  1.0000e-02 acc=0.892000
# [LibSVM]*.*
# optimization finished, #iter = 1290
# obj = -122.759906, rho = -0.688409
# nSV = 760, nBSV = 36
# .*
# optimization finished, #iter = 1766
# obj = -407.684947, rho = 0.101447
# nSV = 970, nBSV = 110
# .*
# optimization finished, #iter = 1617
# obj = -386.119197, rho = 0.036576
# nSV = 972, nBSV = 43
# .*
# optimization finished, #iter = 1658
# obj = -398.657526, rho = 0.077193
# nSV = 1022, nBSV = 81
# .*
# optimization finished, #iter = 1872
# obj = -401.047264, rho = 0.077299
# nSV = 985, nBSV = 92
# .*
# optimization finished, #iter = 1688
# obj = -373.596453, rho = -0.014581
# nSV = 1017, nBSV = 20
# .*
# optimization finished, #iter = 1677
# obj = -337.622410, rho = -0.094398
# nSV = 990, nBSV = 46
# .*
# optimization finished, #iter = 1903
# obj = -401.083438, rho = 0.081601
# nSV = 991, nBSV = 90
# .*
# optimization finished, #iter = 1591
# obj = -348.180486, rho = -0.066508
# nSV = 978, nBSV = 57
# .*.*
# optimization finished, #iter = 2528
# obj = -525.715878, rho = 0.516188
# nSV = 1489, nBSV = 383
# .*
# optimization finished, #iter = 1283
# obj = -126.782276, rho = 0.741869
# nSV = 754, nBSV = 37
# .*
# optimization finished, #iter = 1206
# obj = -125.341814, rho = 0.713316
# nSV = 756, nBSV = 37
# .*
# optimization finished, #iter = 1377
# obj = -128.642685, rho = 0.743443
# nSV = 806, nBSV = 38
# .*
# optimization finished, #iter = 1230
# obj = -126.080047, rho = 0.731436
# nSV = 769, nBSV = 37
# .*
# optimization finished, #iter = 1401
# obj = -124.090853, rho = 0.687915
# nSV = 799, nBSV = 36
# *.*
# optimization finished, #iter = 1253
# obj = -126.302853, rho = 0.662256
# nSV = 781, nBSV = 36
# .*
# optimization finished, #iter = 1280
# obj = -128.076674, rho = 0.741721
# nSV = 775, nBSV = 37
# *.*
# optimization finished, #iter = 1327
# obj = -124.786990, rho = 0.672073
# nSV = 766, nBSV = 36
# .*.*
# optimization finished, #iter = 2319
# obj = -141.934453, rho = 0.889706
# nSV = 1280, nBSV = 44
# .*
# optimization finished, #iter = 1722
# obj = -425.067155, rho = -0.064702
# nSV = 964, nBSV = 113
# .*
# optimization finished, #iter = 1911
# obj = -439.660245, rho = -0.021990
# nSV = 1014, nBSV = 33
# .*
# optimization finished, #iter = 1694
# obj = -439.733729, rho = -0.023272
# nSV = 977, nBSV = 68
# .*
# optimization finished, #iter = 1714
# obj = -401.687801, rho = -0.117718
# nSV = 1008, nBSV = 119
# .*
# optimization finished, #iter = 1586
# obj = -370.268033, rho = -0.197818
# nSV = 982, nBSV = 99
# .*
# optimization finished, #iter = 1869
# obj = -444.618969, rho = -0.018835
# nSV = 983, nBSV = 82
# .*
# optimization finished, #iter = 1798
# obj = -379.583230, rho = -0.172024
# nSV = 970, nBSV = 120
# .*.*
# optimization finished, #iter = 2510
# obj = -585.256153, rho = 0.501631
# nSV = 1481, nBSV = 481
# .*
# optimization finished, #iter = 1659
# obj = -414.799130, rho = 0.040126
# nSV = 1016, nBSV = 73
# .*
# optimization finished, #iter = 1607
# obj = -421.311174, rho = 0.039656
# nSV = 979, nBSV = 87
# .*
# optimization finished, #iter = 1778
# obj = -380.851100, rho = -0.051700
# nSV = 1010, nBSV = 55
# .*
# optimization finished, #iter = 1721
# obj = -353.121735, rho = -0.132758
# nSV = 984, nBSV = 68
# .*
# optimization finished, #iter = 1631
# obj = -423.900305, rho = 0.046039
# nSV = 985, nBSV = 98
# .*
# optimization finished, #iter = 1675
# obj = -365.341476, rho = -0.106494
# nSV = 973, nBSV = 95
# .*.*
# optimization finished, #iter = 2448
# obj = -547.998824, rho = 0.510462
# nSV = 1483, nBSV = 436
# .*
# optimization finished, #iter = 1698
# obj = -432.820557, rho = -0.000783
# nSV = 1029, nBSV = 6
# .*
# optimization finished, #iter = 1744
# obj = -393.911428, rho = -0.093417
# nSV = 1060, nBSV = 99
# .*
# optimization finished, #iter = 1965
# obj = -368.861860, rho = -0.178844
# nSV = 1034, nBSV = 95
# .*
# optimization finished, #iter = 1638
# obj = -436.422771, rho = 0.003659
# nSV = 1035, nBSV = 14
# .*
# optimization finished, #iter = 1691
# obj = -396.911693, rho = -0.160387
# nSV = 1026, nBSV = 143
# ..*
# optimization finished, #iter = 2811
# obj = -590.868528, rho = 0.475441
# nSV = 1533, nBSV = 467
# .*
# optimization finished, #iter = 1807
# obj = -396.048326, rho = -0.093509
# nSV = 1023, nBSV = 99
# .*
# optimization finished, #iter = 1671
# obj = -361.527087, rho = -0.172971
# nSV = 997, nBSV = 84
# .*
# optimization finished, #iter = 1508
# obj = -437.541035, rho = 0.004500
# nSV = 998, nBSV = 28
# .*
# optimization finished, #iter = 1797
# obj = -375.324798, rho = -0.148550
# nSV = 985, nBSV = 115
# .*.*
# optimization finished, #iter = 2203
# obj = -579.523556, rho = 0.494293
# nSV = 1496, nBSV = 484
# .*
# optimization finished, #iter = 1922
# obj = -332.980738, rho = -0.079017
# nSV = 1028, nBSV = 38
# .*
# optimization finished, #iter = 1844
# obj = -397.604693, rho = 0.098204
# nSV = 1029, nBSV = 104
# .*
# optimization finished, #iter = 1782
# obj = -343.536397, rho = -0.050599
# nSV = 1016, nBSV = 47
# ..*
# optimization finished, #iter = 2675
# obj = -518.588863, rho = 0.523048
# nSV = 1527, nBSV = 335
# .*
# optimization finished, #iter = 1664
# obj = -367.632120, rho = 0.180547
# nSV = 1003, nBSV = 94
# .*
# optimization finished, #iter = 1657
# obj = -352.915779, rho = 0.035107
# nSV = 994, nBSV = 46
# ..*
# optimization finished, #iter = 2808
# obj = -463.642724, rho = 0.565961
# nSV = 1501, nBSV = 265
# .*
# optimization finished, #iter = 1829
# obj = -385.953430, rho = -0.157659
# nSV = 993, nBSV = 123
# ..*
# optimization finished, #iter = 2496
# obj = -583.846125, rho = 0.491501
# nSV = 1502, nBSV = 479
# ..*
# optimization finished, #iter = 2726
# obj = -485.224862, rho = 0.562324
# nSV = 1490, nBSV = 309
# Total nSV = 5792
# C=  1.0000e+00 gam=  1.0000e-01 acc=0.396500
# [LibSVM]*
# optimization finished, #iter = 100
# obj = -185.918259, rho = -0.284285
# nSV = 51, nBSV = 17
# *
# optimization finished, #iter = 387
# obj = -446.277790, rho = 0.401610
# nSV = 119, nBSV = 38
# *
# optimization finished, #iter = 305
# obj = -409.476879, rho = -0.272143
# nSV = 109, nBSV = 39
# *
# optimization finished, #iter = 287
# obj = -342.768769, rho = 0.539648
# nSV = 94, nBSV = 26
# *
# optimization finished, #iter = 510
# obj = -698.684364, rho = 1.713942
# nSV = 167, nBSV = 70
# *
# optimization finished, #iter = 382
# obj = -390.845620, rho = -0.276139
# nSV = 116, nBSV = 35
# *
# optimization finished, #iter = 235
# obj = -234.928061, rho = -0.108212
# nSV = 76, nBSV = 21
# *
# optimization finished, #iter = 327
# obj = -440.514228, rho = 0.512989
# nSV = 112, nBSV = 43
# *
# optimization finished, #iter = 248
# obj = -350.917952, rho = -0.131788
# nSV = 90, nBSV = 32
# *
# optimization finished, #iter = 859
# obj = -2200.357842, rho = 5.061259
# nSV = 363, nBSV = 238
# *
# optimization finished, #iter = 270
# obj = -396.798813, rho = 0.993275
# nSV = 104, nBSV = 39
# *
# optimization finished, #iter = 225
# obj = -360.429600, rho = -0.183417
# nSV = 88, nBSV = 31
# *
# optimization finished, #iter = 265
# obj = -398.375204, rho = 1.158262
# nSV = 100, nBSV = 39
# *
# optimization finished, #iter = 262
# obj = -413.577441, rho = 1.577315
# nSV = 97, nBSV = 41
# *
# optimization finished, #iter = 167
# obj = -313.360083, rho = -0.404281
# nSV = 77, nBSV = 32
# *
# optimization finished, #iter = 286
# obj = -402.640427, rho = 0.672904
# nSV = 103, nBSV = 46
# *
# optimization finished, #iter = 329
# obj = -659.733383, rho = 0.921392
# nSV = 137, nBSV = 68
# *
# optimization finished, #iter = 271
# obj = -336.503686, rho = 0.236520
# nSV = 92, nBSV = 33
# *
# optimization finished, #iter = 573
# obj = -1452.659953, rho = 4.852883
# nSV = 244, nBSV = 151
# *
# optimization finished, #iter = 295
# obj = -604.768567, rho = -0.634576
# nSV = 138, nBSV = 71
# *
# optimization finished, #iter = 337
# obj = -466.856975, rho = -0.057274
# nSV = 110, nBSV = 47
# *
# optimization finished, #iter = 498
# obj = -667.792374, rho = 0.583408
# nSV = 155, nBSV = 65
# *
# optimization finished, #iter = 489
# obj = -613.195276, rho = -2.262626
# nSV = 152, nBSV = 61
# *
# optimization finished, #iter = 335
# obj = -406.132071, rho = -0.119750
# nSV = 109, nBSV = 39
# *
# optimization finished, #iter = 518
# obj = -768.742414, rho = -0.606776
# nSV = 171, nBSV = 73
# *
# optimization finished, #iter = 389
# obj = -390.838224, rho = -0.210047
# nSV = 108, nBSV = 31
# *.*
# optimization finished, #iter = 1027
# obj = -2576.446109, rho = 4.887234
# nSV = 414, nBSV = 272
# *
# optimization finished, #iter = 285
# obj = -301.199076, rho = 0.543748
# nSV = 90, nBSV = 26
# *
# optimization finished, #iter = 522
# obj = -1051.470462, rho = 1.892875
# nSV = 204, nBSV = 109
# *
# optimization finished, #iter = 281
# obj = -295.752114, rho = -0.021071
# nSV = 90, nBSV = 23
# *
# optimization finished, #iter = 353
# obj = -486.983855, rho = 0.479395
# nSV = 124, nBSV = 50
# *
# optimization finished, #iter = 503
# obj = -864.589774, rho = 0.937794
# nSV = 181, nBSV = 91
# *
# optimization finished, #iter = 416
# obj = -570.256736, rho = 0.875038
# nSV = 133, nBSV = 51
# *
# optimization finished, #iter = 656
# obj = -1831.342935, rho = 4.936342
# nSV = 295, nBSV = 193
# *
# optimization finished, #iter = 487
# obj = -589.314779, rho = 0.672868
# nSV = 150, nBSV = 58
# *
# optimization finished, #iter = 341
# obj = -381.617221, rho = -0.636776
# nSV = 107, nBSV = 34
# *
# optimization finished, #iter = 388
# obj = -489.923946, rho = -0.437372
# nSV = 125, nBSV = 50
# *
# optimization finished, #iter = 479
# obj = -655.654816, rho = -0.341718
# nSV = 153, nBSV = 62
# *
# optimization finished, #iter = 518
# obj = -1156.386979, rho = -1.228884
# nSV = 216, nBSV = 127
# *.*
# optimization finished, #iter = 1107
# obj = -3359.634424, rho = 4.250120
# nSV = 503, nBSV = 361
# *
# optimization finished, #iter = 343
# obj = -666.059436, rho = -2.178780
# nSV = 147, nBSV = 69
# *
# optimization finished, #iter = 356
# obj = -386.240525, rho = -1.003769
# nSV = 113, nBSV = 31
# *
# optimization finished, #iter = 771
# obj = -1077.504731, rho = -1.733189
# nSV = 232, nBSV = 106
# *
# optimization finished, #iter = 412
# obj = -610.683453, rho = -1.147356
# nSV = 143, nBSV = 58
# *.*
# optimization finished, #iter = 1308
# obj = -3339.476842, rho = 4.285053
# nSV = 517, nBSV = 362
# *
# optimization finished, #iter = 204
# obj = -145.277919, rho = 0.263949
# nSV = 63, nBSV = 6
# *
# optimization finished, #iter = 355
# obj = -437.386768, rho = 0.542869
# nSV = 118, nBSV = 40
# *
# optimization finished, #iter = 273
# obj = -224.583467, rho = 0.435841
# nSV = 76, nBSV = 15
# *
# optimization finished, #iter = 732
# obj = -1962.723562, rho = 6.449178
# nSV = 328, nBSV = 209
# *
# optimization finished, #iter = 565
# obj = -552.674411, rho = 0.345906
# nSV = 154, nBSV = 47
# *
# optimization finished, #iter = 575
# obj = -1382.072220, rho = -0.005403
# nSV = 238, nBSV = 151
# *
# optimization finished, #iter = 629
# obj = -1316.957205, rho = 4.784127
# nSV = 246, nBSV = 147
# *
# optimization finished, #iter = 585
# obj = -984.153366, rho = 0.202870
# nSV = 203, nBSV = 108
# *.*
# optimization finished, #iter = 1127
# obj = -3587.934118, rho = 9.762194
# nSV = 518, nBSV = 380
# *
# optimization finished, #iter = 795
# obj = -2014.206214, rho = 5.353463
# nSV = 331, nBSV = 210
# Total nSV = 3227
# C=  1.0000e+01 gam=  1.0000e-03 acc=0.853500
# [LibSVM]*
# optimization finished, #iter = 185
# obj = -26.461959, rho = -0.354682
# nSV = 80, nBSV = 0
# *
# optimization finished, #iter = 460
# obj = -64.302042, rho = 0.191476
# nSV = 190, nBSV = 0
# *
# optimization finished, #iter = 406
# obj = -58.450113, rho = -0.027599
# nSV = 176, nBSV = 0
# *
# optimization finished, #iter = 395
# obj = -50.971323, rho = 0.353862
# nSV = 171, nBSV = 0
# *
# optimization finished, #iter = 613
# obj = -90.536661, rho = 0.478578
# nSV = 229, nBSV = 0
# *
# optimization finished, #iter = 442
# obj = -64.065680, rho = -0.131810
# nSV = 172, nBSV = 0
# *
# optimization finished, #iter = 299
# obj = -37.137714, rho = -0.077941
# nSV = 130, nBSV = 0
# *
# optimization finished, #iter = 411
# obj = -63.477136, rho = 0.253236
# nSV = 174, nBSV = 0
# *
# optimization finished, #iter = 368
# obj = -56.193586, rho = -0.011896
# nSV = 156, nBSV = 0
# *.*
# optimization finished, #iter = 1295
# obj = -295.487689, rho = 1.730540
# nSV = 427, nBSV = 0
# *
# optimization finished, #iter = 323
# obj = -59.946603, rho = 0.759426
# nSV = 127, nBSV = 0
# *
# optimization finished, #iter = 315
# obj = -49.791643, rho = 0.070385
# nSV = 122, nBSV = 0
# *
# optimization finished, #iter = 431
# obj = -61.536908, rho = 0.779374
# nSV = 144, nBSV = 0
# *
# optimization finished, #iter = 348
# obj = -59.431028, rho = 0.947423
# nSV = 127, nBSV = 0
# *
# optimization finished, #iter = 267
# obj = -45.461170, rho = 0.070404
# nSV = 101, nBSV = 0
# *
# optimization finished, #iter = 354
# obj = -65.459544, rho = 0.402321
# nSV = 119, nBSV = 0
# *
# optimization finished, #iter = 438
# obj = -87.403405, rho = 0.491041
# nSV = 157, nBSV = 0
# *
# optimization finished, #iter = 336
# obj = -49.876175, rho = 0.302893
# nSV = 122, nBSV = 0
# *
# optimization finished, #iter = 996
# obj = -237.499647, rho = 2.190770
# nSV = 270, nBSV = 1
# *
# optimization finished, #iter = 537
# obj = -93.284228, rho = -0.275555
# nSV = 201, nBSV = 0
# *
# optimization finished, #iter = 465
# obj = -67.137752, rho = -0.009135
# nSV = 190, nBSV = 0
# *
# optimization finished, #iter = 573
# obj = -89.101333, rho = 0.137504
# nSV = 235, nBSV = 0
# *
# optimization finished, #iter = 529
# obj = -75.123427, rho = -0.818449
# nSV = 213, nBSV = 0
# *
# optimization finished, #iter = 463
# obj = -67.709969, rho = -0.079867
# nSV = 173, nBSV = 0
# *
# optimization finished, #iter = 660
# obj = -110.053014, rho = 0.014529
# nSV = 258, nBSV = 0
# *
# optimization finished, #iter = 420
# obj = -62.405733, rho = 0.024242
# nSV = 169, nBSV = 0
# .*
# optimization finished, #iter = 1569
# obj = -388.229925, rho = 1.821617
# nSV = 534, nBSV = 0
# *
# optimization finished, #iter = 370
# obj = -47.180582, rho = 0.259227
# nSV = 157, nBSV = 0
# *
# optimization finished, #iter = 752
# obj = -149.354553, rho = 0.688761
# nSV = 274, nBSV = 0
# *
# optimization finished, #iter = 372
# obj = -47.402813, rho = -0.000081
# nSV = 150, nBSV = 0
# *
# optimization finished, #iter = 469
# obj = -77.042851, rho = 0.227113
# nSV = 185, nBSV = 0
# *
# optimization finished, #iter = 689
# obj = -128.739879, rho = 0.465605
# nSV = 253, nBSV = 0
# *
# optimization finished, #iter = 524
# obj = -83.657860, rho = 0.377794
# nSV = 190, nBSV = 0
# *.*
# optimization finished, #iter = 1201
# obj = -269.007721, rho = 2.002997
# nSV = 400, nBSV = 0
# *
# optimization finished, #iter = 539
# obj = -77.666766, rho = 0.037027
# nSV = 203, nBSV = 0
# *
# optimization finished, #iter = 414
# obj = -57.751233, rho = -0.428950
# nSV = 170, nBSV = 0
# *
# optimization finished, #iter = 447
# obj = -78.620199, rho = -0.458102
# nSV = 175, nBSV = 0
# *
# optimization finished, #iter = 639
# obj = -93.184742, rho = -0.039517
# nSV = 248, nBSV = 0
# *
# optimization finished, #iter = 886
# obj = -172.373954, rho = -0.758141
# nSV = 299, nBSV = 0
# .*.*
# optimization finished, #iter = 2099
# obj = -494.956764, rho = 1.140027
# nSV = 595, nBSV = 0
# *
# optimization finished, #iter = 564
# obj = -91.290591, rho = -0.756201
# nSV = 208, nBSV = 0
# *
# optimization finished, #iter = 455
# obj = -55.528505, rho = -0.421090
# nSV = 179, nBSV = 0
# *
# optimization finished, #iter = 852
# obj = -146.650782, rho = -0.422163
# nSV = 303, nBSV = 0
# *
# optimization finished, #iter = 528
# obj = -86.666451, rho = -0.412673
# nSV = 208, nBSV = 0
# .*.*
# optimization finished, #iter = 2071
# obj = -464.192526, rho = 1.174178
# nSV = 615, nBSV = 0
# *
# optimization finished, #iter = 253
# obj = -25.341840, rho = 0.080826
# nSV = 112, nBSV = 0
# *
# optimization finished, #iter = 429
# obj = -69.395989, rho = 0.415218
# nSV = 169, nBSV = 0
# *
# optimization finished, #iter = 256
# obj = -36.182745, rho = 0.200343
# nSV = 117, nBSV = 0
# *.*
# optimization finished, #iter = 1211
# obj = -273.799694, rho = 2.202699
# nSV = 384, nBSV = 0
# *
# optimization finished, #iter = 570
# obj = -83.131450, rho = 0.277184
# nSV = 209, nBSV = 0
# *.*
# optimization finished, #iter = 1045
# obj = -237.754397, rho = 0.058299
# nSV = 296, nBSV = 1
# *
# optimization finished, #iter = 891
# obj = -184.820560, rho = 1.867243
# nSV = 297, nBSV = 0
# *
# optimization finished, #iter = 718
# obj = -143.559108, rho = -0.070420
# nSV = 261, nBSV = 0
# .*.*
# optimization finished, #iter = 2064
# obj = -494.975923, rho = 2.600646
# nSV = 631, nBSV = 0
# *.*
# optimization finished, #iter = 1441
# obj = -350.650041, rho = 2.006757
# nSV = 442, nBSV = 1
# Total nSV = 3726
# C=  1.0000e+01 gam=  1.0000e-02 acc=0.906333
# [LibSVM].*
# optimization finished, #iter = 1346
# obj = -125.713313, rho = -0.663218
# nSV = 760, nBSV = 0
# .*
# optimization finished, #iter = 1624
# obj = -407.840148, rho = 0.095199
# nSV = 970, nBSV = 0
# .*
# optimization finished, #iter = 1608
# obj = -386.128839, rho = 0.035585
# nSV = 972, nBSV = 0
# .*
# optimization finished, #iter = 1686
# obj = -398.732291, rho = 0.073467
# nSV = 1022, nBSV = 0
# .*
# optimization finished, #iter = 1701
# obj = -401.124086, rho = 0.073287
# nSV = 985, nBSV = 0
# .*
# optimization finished, #iter = 1657
# obj = -373.610818, rho = -0.014545
# nSV = 1017, nBSV = 0
# .*
# optimization finished, #iter = 1652
# obj = -337.682335, rho = -0.091445
# nSV = 990, nBSV = 0
# .*
# optimization finished, #iter = 1691
# obj = -401.170657, rho = 0.077409
# nSV = 991, nBSV = 0
# .*
# optimization finished, #iter = 1585
# obj = -348.255496, rho = -0.063121
# nSV = 978, nBSV = 0
# ..*
# optimization finished, #iter = 2965
# obj = -540.985437, rho = 0.444072
# nSV = 1489, nBSV = 0
# .*
# optimization finished, #iter = 1369
# obj = -130.422529, rho = 0.717830
# nSV = 752, nBSV = 0
# .*
# optimization finished, #iter = 1324
# obj = -128.658103, rho = 0.688034
# nSV = 756, nBSV = 0
# .*
# optimization finished, #iter = 1331
# obj = -132.373998, rho = 0.717961
# nSV = 806, nBSV = 0
# .*
# optimization finished, #iter = 1450
# obj = -129.607524, rho = 0.707027
# nSV = 769, nBSV = 0
# .*
# optimization finished, #iter = 1429
# obj = -127.126584, rho = 0.661896
# nSV = 798, nBSV = 0
# .*
# optimization finished, #iter = 1380
# obj = -129.134786, rho = 0.633012
# nSV = 783, nBSV = 0
# .*
# optimization finished, #iter = 1441
# obj = -131.752388, rho = 0.716659
# nSV = 775, nBSV = 0
# .*
# optimization finished, #iter = 1405
# obj = -127.671293, rho = 0.644023
# nSV = 768, nBSV = 0
# .*.*
# optimization finished, #iter = 2467
# obj = -148.049074, rho = 0.874062
# nSV = 1281, nBSV = 0
# .*
# optimization finished, #iter = 1771
# obj = -425.149768, rho = -0.060070
# nSV = 964, nBSV = 0
# .*
# optimization finished, #iter = 1942
# obj = -439.662654, rho = -0.021638
# nSV = 1014, nBSV = 0
# .*
# optimization finished, #iter = 1695
# obj = -439.739714, rho = -0.022343
# nSV = 977, nBSV = 0
# .*
# optimization finished, #iter = 1783
# obj = -401.907623, rho = -0.109793
# nSV = 1008, nBSV = 0
# .*
# optimization finished, #iter = 1778
# obj = -370.790838, rho = -0.186572
# nSV = 982, nBSV = 0
# .*
# optimization finished, #iter = 1867
# obj = -444.629816, rho = -0.017952
# nSV = 983, nBSV = 0
# .*
# optimization finished, #iter = 1889
# obj = -380.217898, rho = -0.157586
# nSV = 970, nBSV = 0
# ...*
# optimization finished, #iter = 3781
# obj = -615.272836, rho = 0.362391
# nSV = 1481, nBSV = 0
# .*
# optimization finished, #iter = 1659
# obj = -414.820522, rho = 0.038252
# nSV = 1016, nBSV = 0
# .*
# optimization finished, #iter = 1625
# obj = -421.353157, rho = 0.037833
# nSV = 979, nBSV = 0
# .*
# optimization finished, #iter = 1760
# obj = -380.870364, rho = -0.050142
# nSV = 1010, nBSV = 0
# .*
# optimization finished, #iter = 1649
# obj = -353.398897, rho = -0.127370
# nSV = 984, nBSV = 0
# .*
# optimization finished, #iter = 1627
# obj = -423.961767, rho = 0.042913
# nSV = 985, nBSV = 0
# .*
# optimization finished, #iter = 1598
# obj = -365.570564, rho = -0.099212
# nSV = 973, nBSV = 0
# ..*
# optimization finished, #iter = 2901
# obj = -568.045061, rho = 0.414474
# nSV = 1483, nBSV = 0
# .*
# optimization finished, #iter = 1689
# obj = -432.821857, rho = -0.000715
# nSV = 1029, nBSV = 0
# .*
# optimization finished, #iter = 1743
# obj = -394.025346, rho = -0.088243
# nSV = 1060, nBSV = 0
# .*
# optimization finished, #iter = 1760
# obj = -369.362605, rho = -0.167780
# nSV = 1034, nBSV = 0
# .*
# optimization finished, #iter = 1643
# obj = -436.429686, rho = 0.003794
# nSV = 1035, nBSV = 0
# .*
# optimization finished, #iter = 1901
# obj = -397.650559, rho = -0.142965
# nSV = 1026, nBSV = 0
# ..*.*
# optimization finished, #iter = 3494
# obj = -608.633403, rho = 0.386454
# nSV = 1533, nBSV = 0
# .*
# optimization finished, #iter = 1821
# obj = -396.174012, rho = -0.088044
# nSV = 1023, nBSV = 0
# .*
# optimization finished, #iter = 1702
# obj = -361.888571, rho = -0.164053
# nSV = 997, nBSV = 0
# .*
# optimization finished, #iter = 1506
# obj = -437.542834, rho = 0.004545
# nSV = 998, nBSV = 0
# .*
# optimization finished, #iter = 1873
# obj = -375.774115, rho = -0.136442
# nSV = 985, nBSV = 0
# ..*.*
# optimization finished, #iter = 3778
# obj = -602.000403, rho = 0.384291
# nSV = 1496, nBSV = 0
# .*
# optimization finished, #iter = 1829
# obj = -333.015049, rho = -0.076951
# nSV = 1028, nBSV = 0
# .*
# optimization finished, #iter = 1883
# obj = -397.756312, rho = 0.092463
# nSV = 1029, nBSV = 0
# .*
# optimization finished, #iter = 1704
# obj = -343.562514, rho = -0.048603
# nSV = 1016, nBSV = 0
# ..*.*
# optimization finished, #iter = 3421
# obj = -533.107035, rho = 0.457702
# nSV = 1527, nBSV = 0
# .*
# optimization finished, #iter = 1655
# obj = -368.063616, rho = 0.170384
# nSV = 1003, nBSV = 0
# .*
# optimization finished, #iter = 1630
# obj = -353.092027, rho = 0.033450
# nSV = 994, nBSV = 0
# .*.*
# optimization finished, #iter = 2706
# obj = -474.600862, rho = 0.517359
# nSV = 1501, nBSV = 0
# .*
# optimization finished, #iter = 1860
# obj = -386.541309, rho = -0.143810
# nSV = 993, nBSV = 0
# ..*.*
# optimization finished, #iter = 3744
# obj = -606.976961, rho = 0.381434
# nSV = 1502, nBSV = 0
# ..*
# optimization finished, #iter = 2815
# obj = -500.370631, rho = 0.498206
# nSV = 1490, nBSV = 0
# Total nSV = 5794
# C=  1.0000e+01 gam=  1.0000e-01 acc=0.443167

# %%
# TODO 15:  Print the accuracy matrix
print(acc)
# Out:
# [[0.52416667 0.81666667 0.22683333]
#  [0.81716667 0.892      0.3965    ]
#  [0.8535     0.90633333 0.44316667]]

# %%
# TODO 16:  Print the maximum accuracy and the corresponding best C and gamma

acc_max = np.max(acc)
ind = np.argmax(acc)
i, j = np.unravel_index(ind, (nC,ngam))
print('Max accuracy = %12.4e' % acc_max)
print('Optimal C=%12.4e gam = %12.4e' % (C_test[i], gam_test[j]))
# Out:
# Max accuracy =   9.0633e-01
# Optimal C=  1.0000e+01 gam =   1.0000e-02

# %% [markdown]
# ## Using `GridSearchCV` (Optional Section)
#
#
# In the previous section, you would have likely used `for-loops` to search over the different `C` and `gamma` values.  Since this type of parameter search is so commonly used, `sklearn` has an excellent method `GridSearchCV` that can perform all the operations for you.  In this lab, `GridSearchCV` is not that useful.  But, once you get to more complex parameter searches, the `GridSearchCV` method can save you writing a lot of code.  Importantly, `GridSearchCV` supports parallelization so that fits with different parameters can be fit at the same time.  In this optional section, we will show how to use this method.
#
# **You do not have to do this section, if you did the previous section**.

# %% [markdown]
# The `GridSearchCV` method does the train-test split in addition to the parameter search.  In this case, you have already a fixed train-test split.  So, you first need to combine the train and test data back into a single dataset.
#
# Create arrays `X` and `y` from `Xtr1`, `Xts1`, `ytr` and `yts`.  Use `np.vstack` and `np.hstack`.

# %%
# TODO 17:  Create combined trained and test data X and y.
# X = ...
# y = ...

X = np.vstack((Xtr1,Xts1))
y = np.hstack((ytr,yts))

# %% [markdown]
# Normally, `GridSearchCV` will do $K$-fold validation and automatically split the data into training and test in each fold.  But, in this case, we want it to perform only one fold with a specific train-test split.  To do this, we need to do the following:
# * Create a vector `test_fold` where `test_fold[i] = -1` for the samples `i` in the training data (this indicates that they should not be used as test data in any fold) and `test_fold[i] = 0` for the samples `i` in the test data (this indicates that they should be as test data in fold 0).
# * Call the method  `ps = sklearn.model_selection.PredefinedSplit(test_fold)` to create a predefined test split object.

# %%
# TODO 18:  Create a pre-defined test split object 
# import sklearn.model_selection
# test_fold = ...
# ps = sklearn.model_selection.PredefinedSplit(test_fold)


ntr = len(ytr)
nts = len(yts)
test_fold = np.hstack((-1*np.ones(ntr), np.zeros(nts)))

import sklearn.model_selection
ps = sklearn.model_selection.PredefinedSplit(test_fold)

# %% [markdown]
# Next, read about the `GridSearchCV` method to set up a classifier that includes searching over the parameter grid.
# * For the `param_grid` parameter, you will want to create a dictionary to search over `C` and `gamma`.  You will also need to select the `kernel` parameter.
# * Set `cv = ps` to use the fixed train-test split.
# * Set `verbose=10` to monitor the progress

# %%
# TODO 19:  Create a GridSearchCV classifier
# clf = ...
from sklearn.model_selection import GridSearchCV

param_grid = {'C' : C_test, 'gamma': gam_test, 'kernel' : ['rbf']}

clf = GridSearchCV(svm.SVC(), param_grid = param_grid, cv = ps, verbose=10)

# %% [markdown]
# Fit the classifier using the `fit` method.  The fit method will now search over all the parameters. This will take about 30 minutes.

# %%
# TODO 20: Fit the classifier

clf.fit(X,y)
# Out:
# Fitting 1 folds for each of 9 candidates, totalling 9 fits
# [CV 1/1; 1/9] START C=0.1, gamma=0.001, kernel=rbf..............................
# [CV 1/1; 1/9] END C=0.1, gamma=0.001, kernel=rbf;, score=0.524 total time=  22.8s
# [CV 1/1; 2/9] START C=0.1, gamma=0.01, kernel=rbf...............................
# [CV 1/1; 2/9] END C=0.1, gamma=0.01, kernel=rbf;, score=0.817 total time=  17.7s
# [CV 1/1; 3/9] START C=0.1, gamma=0.1, kernel=rbf................................
# [CV 1/1; 3/9] END .C=0.1, gamma=0.1, kernel=rbf;, score=0.227 total time=  26.9s
# [CV 1/1; 4/9] START C=1, gamma=0.001, kernel=rbf................................
# [CV 1/1; 4/9] END .C=1, gamma=0.001, kernel=rbf;, score=0.817 total time=  13.7s
# [CV 1/1; 5/9] START C=1, gamma=0.01, kernel=rbf.................................
# [CV 1/1; 5/9] END ..C=1, gamma=0.01, kernel=rbf;, score=0.892 total time=  11.0s
# [CV 1/1; 6/9] START C=1, gamma=0.1, kernel=rbf..................................
# [CV 1/1; 6/9] END ...C=1, gamma=0.1, kernel=rbf;, score=0.397 total time=  26.4s
# [CV 1/1; 7/9] START C=10, gamma=0.001, kernel=rbf...............................
# [CV 1/1; 7/9] END C=10, gamma=0.001, kernel=rbf;, score=0.854 total time=   9.1s
# [CV 1/1; 8/9] START C=10, gamma=0.01, kernel=rbf................................
# [CV 1/1; 8/9] END .C=10, gamma=0.01, kernel=rbf;, score=0.906 total time=  10.9s
# [CV 1/1; 9/9] START C=10, gamma=0.1, kernel=rbf.................................
# [CV 1/1; 9/9] END ..C=10, gamma=0.1, kernel=rbf;, score=0.443 total time=  27.1s
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#              estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10], 'gamma': [0.001, 0.01, 0.1],
#                          'kernel': ['rbf']},
#              verbose=10)

# %% [markdown]
# Print the `best_score_` and `best_params_` attributes of the classifier to find the best score and parameters

# %%
# TODO 21:  Print the best parameter and score of the classifier

print("Best parameter: " + str(clf.best_params_))
print("Best score: " + str(clf.best_score_))
# Out:
# Best parameter: {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# Best score: 0.9063333333333333

# %% [markdown]
# Finally, you can print the test and train score from the `cv_results_['mean_test_score']` and `cv_results_['mean_train_score']`.

# %%
# TODO 22:  Print the mean test score for each parameter value.


clf.cv_results_['mean_test_score']
# Out:
# array([0.52416667, 0.81666667, 0.22683333, 0.81716667, 0.892     ,
#        0.3965    , 0.8535    , 0.90633333, 0.44316667])
